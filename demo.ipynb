# %%
# !pip install ultralytics
# Out:
# ...
#      ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.2 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/41.2 kB 165.2 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/41.2 kB 187.9 kB/s eta 0:00:01
#      -------------------------------------- 41.2/41.2 kB 198.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 640.0 kB/s eta 0:00:01
#      ---------------------------------------- 61.0/61.0 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# !pip install opencv-python

# %%
from ultralytics import YOLO

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO('yolov8n.pt')  # You can replace 'yolov8n.pt' with any YOLOv8 model variant

# Access the webcam
cap = cv2.VideoCapture(0)  # 0 is the default camera

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Inference
    results = model(frame)

    # Render results
    annotated_frame = results[0].plot()  # Draws the boxes and labels on the frame

    # Display the resulting frame
    cv2.imshow('YOLOv8 Webcam', annotated_frame)

    # Press 'q' to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 15.7MB/s]
# 0: 480x640 1 person, 385.5ms
# Speed: 27.3ms preprocess, 385.5ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 280.6ms
# Speed: 5.5ms preprocess, 280.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 291.8ms
# Speed: 11.6ms preprocess, 291.8ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 329.4ms
# Speed: 10.8ms preprocess, 329.4ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 298.7ms
# Speed: 6.1ms preprocess, 298.7ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 361.1ms
# Speed: 3.8ms preprocess, 361.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 256.9ms
# Speed: 3.3ms preprocess, 256.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
import torch
import cv2
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO('best.pt')  # You can replace 'yolov8n.pt' with any YOLOv8 model variant

# Input video file path
input_video_path = 'nba-vid.mp4'

# Output video file path
output_video_path = 'output_video.mp4'

# Open the input video
cap = cv2.VideoCapture(input_video_path)

# Get the width and height of the video frames
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create VideoWriter object to save the output video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # You can use other codecs as well
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Inference
    results = model(frame)

    # Render results
    annotated_frame = results[0].plot()  # Draws the boxes and labels on the frame

    # Write the annotated frame to the output video
    out.write(annotated_frame)

    # Display the resulting frame (optional)
    cv2.imshow('YOLOv8 Video', annotated_frame)

    # Press 'q' to exit the loop (optional)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and writer objects and close all OpenCV windows
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 Players, 2 Refs, 1 Team Points, 224.1ms
# Speed: 6.0ms preprocess, 224.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Players, 2 Refs, 1 Team Points, 180.1ms
# Speed: 4.5ms preprocess, 180.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Players, 2 Refs, 1 Team Points, 190.9ms
# Speed: 4.8ms preprocess, 190.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Players, 2 Refs, 1 Team Points, 204.7ms
# Speed: 4.5ms preprocess, 204.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Players, 2 Refs, 1 Team Points, 220.2ms
# Speed: 3.7ms preprocess, 220.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Players, 2 Refs, 1 Team Points, 198.8ms
# Speed: 5.6ms preprocess, 198.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Players, 2 Refs, 1 Team Points, 190.7ms
# ...
